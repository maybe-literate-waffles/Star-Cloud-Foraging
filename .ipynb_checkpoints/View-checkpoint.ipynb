# %%
from scraping import get_data
from IPython.display import JSON
import panda as pnd

data = get_data()

df = pnd.json_normalize(raw_data, sep="_")

# JSON(data, expanded=True)

print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from scraping import get_data
#       2 from IPython.display import JSON
# ----> 3 import pandas as pnd
#       4
#       5 data = get_data()
#       6
#
# ModuleNotFoundError: No module named 'pandas'
