# %%
from scraping import get_data
from IPython.display import JSON
import pandas as pnd

data = get_data()

df = pnd.json_normalize(data, sep="_")

# JSON(data, expanded=True)

print(df)
# Out:
#     latitude  longitude  generationtime_ms  utc_offset_seconds  \
# 0  35.700000  139.62500           0.015974               32400
# 1  51.500000   -0.25000           0.033140                3600
# 2   1.370826  103.80237           0.012636               28800
# 3  40.710335  -73.99308           0.014424              -14400
# 4 -33.848858  151.19551           0.049114               36000
#
#            timezone timezone_abbreviation  elevation current_units_time  \
# 0        Asia/Tokyo                 GMT+9       37.0            iso8601
# 1     Europe/London                 GMT+1       16.0            iso8601
# 2    Asia/Singapore                 GMT+8       46.0            iso8601
# 3  America/New_York                 GMT-4       32.0            iso8601
# 4  Australia/Sydney                GMT+10       86.0            iso8601
#
#   current_units_interval current_units_temperature_2m      current_time  \
# 0                seconds                           °C  2026-07-20T04:15
# ...
